# %%
import pandas as pd

# %% [markdown]
# ## Data Loading

# %%
df = pd.read_csv('Train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23856 entries, 0 to 23855
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   INCIDENT_ID       23856 non-null  object
#  1   DATE              23856 non-null  object
#  2   X_1               23856 non-null  int64
#  3   X_2               23856 non-null  int64
#  4   X_3               23856 non-null  int64
#  5   X_4               23856 non-null  int64
#  6   X_5               23856 non-null  int64
#  7   X_6               23856 non-null  int64
#  8   X_7               23856 non-null  int64
#  9   X_8               23856 non-null  int64
#  10  X_9               23856 non-null  int64
#  11  X_10              23856 non-null  int64
#  12  X_11              23856 non-null  int64
#  13  X_12              23674 non-null  float64
#  14  X_13              23856 non-null  int64
#  15  X_14              23856 non-null  int64
# ...

# %% [markdown]
# ## Preprocessing Data

# %%
df.drop(['DATE','INCIDENT_ID'],inplace=True,axis=1)

# %%
df.describe()
# Out:
#                 X_1           X_2           X_3           X_4           X_5  \
# count  23856.000000  23856.000000  23856.000000  23856.000000  23856.000000
# mean       0.483778     24.791206     24.637450      4.276744      2.455609
# std        1.439738     15.240231     15.135093      2.944672      1.963095
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      7.000000      8.000000      2.000000      1.000000
# 50%        0.000000     24.000000     24.000000      4.000000      3.000000
# 75%        0.000000     36.000000     35.000000      6.000000      5.000000
# max        7.000000     52.000000     52.000000     10.000000      5.000000
#
#                 X_6           X_7           X_8           X_9          X_10  \
# count  23856.000000  23856.000000  23856.000000  23856.000000  23856.000000
# mean       6.154175      4.876509      0.972460      4.924128      1.244802
# ...

# %%
df.fillna(df['X_12'].mean(),inplace=True)

# %%
df.describe()
# Out:
#                 X_1           X_2           X_3           X_4           X_5  \
# count  23856.000000  23856.000000  23856.000000  23856.000000  23856.000000
# mean       0.483778     24.791206     24.637450      4.276744      2.455609
# std        1.439738     15.240231     15.135093      2.944672      1.963095
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      7.000000      8.000000      2.000000      1.000000
# 50%        0.000000     24.000000     24.000000      4.000000      3.000000
# 75%        0.000000     36.000000     35.000000      6.000000      5.000000
# max        7.000000     52.000000     52.000000     10.000000      5.000000
#
#                 X_6           X_7           X_8           X_9          X_10  \
# count  23856.000000  23856.000000  23856.000000  23856.000000  23856.000000
# mean       6.154175      4.876509      0.972460      4.924128      1.244802
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23856 entries, 0 to 23855
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   X_1               23856 non-null  int64
#  1   X_2               23856 non-null  int64
#  2   X_3               23856 non-null  int64
#  3   X_4               23856 non-null  int64
#  4   X_5               23856 non-null  int64
#  5   X_6               23856 non-null  int64
#  6   X_7               23856 non-null  int64
#  7   X_8               23856 non-null  int64
#  8   X_9               23856 non-null  int64
#  9   X_10              23856 non-null  int64
#  10  X_11              23856 non-null  int64
#  11  X_12              23856 non-null  float64
#  12  X_13              23856 non-null  int64
#  13  X_14              23856 non-null  int64
#  14  X_15              23856 non-null  int64
#  15  MULTIPLE_OFFENSE  23856 non-null  int64
# dtypes: float64(1), int64(15)
# ...

# %% [markdown]
# ## EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x='MULTIPLE_OFFENSE',data=df)

# %%
sns.set_style('whitegrid')
sns.pairplot(df)

# %%
y=df['MULTIPLE_OFFENSE']
x=df.iloc[:,:15]

# %%
print(x.shape,y.shape)
# Out:
# (23856, 15) (23856,)

# %% [markdown]
# ## Spliting and Scalling the datat

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
scaler = MinMaxScaler()
x = scaler.fit_transform(x)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.2)

# %% [markdown]
# ## Finding the Hyperparameter

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# %%
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]
parameters = {'n_estimators': n_estimators,'max_features': max_features,'max_depth': max_depth,'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,'bootstrap': bootstrap}

# %%
rfc = RandomForestClassifier()

# %%
rsc=RandomizedSearchCV(estimator=rfc,param_distributions=parameters,n_iter=100,cv=3,random_state=42,n_jobs=-1)

# %%
rsc.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=3, error_score=nan,
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     ccp_alpha=0.0,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
#                                                     max_samples=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
# ...

# %%
print(rsc.best_params_)
# Out:
# {'n_estimators': 800, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 90, 'bootstrap': False}

# %% [markdown]
# ## Making a Model

# %%
from sklearn.metrics import recall_score

# %%
clf = RandomForestClassifier(n_estimators= 800, min_samples_split=5, min_samples_leaf=1,max_features='sqrt', max_depth=90, 
                             bootstrap=False)
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=90, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=5,
#                        min_weight_fraction_leaf=0.0, n_estimators=800,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
pred = clf.predict(x_test)

# %%
recall_score(y_test,pred)
# Out:
# 0.9991183601498788

# %% [markdown]
# ## Loading the Test data

# %%
df_test =pd.read_csv("Test.csv")
df_test.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  \
# 0   CR_195453  01-FEB-18    0   30   35    7    3    6    4    0    5     1
# 1   CR_103520  05-MAR-04    0   44   44    1    3    7    1    4    6     1
# 2   CR_196089  27-JAN-18    0   34   33    3    5    2    7    3    0     1
# 3   CR_112195  18-AUG-06    7    3    2    3    5    9    8    0    5     1
# 4   CR_149832  31-OCT-11    0    7    8    7    3    2    7    1    5     1
#
#    X_11  X_12  X_13  X_14  X_15
# 0   174   NaN    72   119    23
# 1   316   0.0    12    29    34
# 2   316   1.0    72     0    34
# 3   174   1.0   112    87    34
# 4   174   0.0   112    93    43

# %%
df_test.drop(['DATE'],inplace=True,axis=1)

# %%
df_test.head()
# Out:
#   INCIDENT_ID  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  X_11  X_12  \
# 0   CR_195453    0   30   35    7    3    6    4    0    5     1   174   NaN
# 1   CR_103520    0   44   44    1    3    7    1    4    6     1   316   0.0
# 2   CR_196089    0   34   33    3    5    2    7    3    0     1   316   1.0
# 3   CR_112195    7    3    2    3    5    9    8    0    5     1   174   1.0
# 4   CR_149832    0    7    8    7    3    2    7    1    5     1   174   0.0
#
#    X_13  X_14  X_15
# 0    72   119    23
# 1    12    29    34
# 2    72     0    34
# 3   112    87    34
# 4   112    93    43

# %%
df_result=pd.DataFrame(df_test['INCIDENT_ID'])

# %%
df_test.drop(['INCIDENT_ID'],inplace=True,axis=1)

# %%
df_test.head()
# Out:
#    X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  X_11  X_12  X_13  X_14  \
# 0    0   30   35    7    3    6    4    0    5     1   174   NaN    72   119
# 1    0   44   44    1    3    7    1    4    6     1   316   0.0    12    29
# 2    0   34   33    3    5    2    7    3    0     1   316   1.0    72     0
# 3    7    3    2    3    5    9    8    0    5     1   174   1.0   112    87
# 4    0    7    8    7    3    2    7    1    5     1   174   0.0   112    93
#
#    X_15
# 0    23
# 1    34
# 2    34
# 3    34
# 4    43

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15903 entries, 0 to 15902
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X_1     15903 non-null  int64
#  1   X_2     15903 non-null  int64
#  2   X_3     15903 non-null  int64
#  3   X_4     15903 non-null  int64
#  4   X_5     15903 non-null  int64
#  5   X_6     15903 non-null  int64
#  6   X_7     15903 non-null  int64
#  7   X_8     15903 non-null  int64
#  8   X_9     15903 non-null  int64
#  9   X_10    15903 non-null  int64
#  10  X_11    15903 non-null  int64
#  11  X_12    15776 non-null  float64
#  12  X_13    15903 non-null  int64
#  13  X_14    15903 non-null  int64
#  14  X_15    15903 non-null  int64
# dtypes: float64(1), int64(14)
# memory usage: 1.8 MB

# %%
df_test.fillna(df_test['X_12'].mean(),inplace=True)

# %%
x_final = scaler.transform(df_test)

# %%
pred_result = clf.predict(x_final)

# %%
pred_result=list(pred_result)

# %%
df_result.shape
# Out:
# (15903, 1)

# %%
type(pred_result)
# Out:
# list

# %%
df_result['MULTIPLE_OFFENSE']=pred_result

# %%
df_result
# Out:
#       INCIDENT_ID  MULTIPLE_OFFENSE
# 0       CR_195453                 1
# 1       CR_103520                 1
# 2       CR_196089                 1
# 3       CR_112195                 1
# 4       CR_149832                 1
# ...           ...               ...
# 15898    CR_44468                 1
# 15899   CR_158460                 1
# 15900   CR_115946                 1
# 15901   CR_137663                 1
# 15902    CR_33545                 1
#
# [15903 rows x 2 columns]

# %%
df_result.to_csv('predication_improve.csv',index=False)
